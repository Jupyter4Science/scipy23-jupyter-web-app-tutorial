# %% [markdown]
# # Deploying Your Dashboard

# %% [markdown]
# So now we have all the components in our dashboard, but we want it to be more accessible to the world. How do we approach this?

# %% [markdown]
# ## Voilà
#
# [Voilà](https://github.com/voila-dashboards/voila) turns Jupyter notebooks into standalone web applications. But how? Basically, it renders your notebook without actually showing the code cells. It only shows markdown cells and the widget outputs. This also makes sure your user can't run arbitrary code.
#
# ### Preview
#
# First, let's make sure we have 04_dashboard.ipynb open to the side. Now, lets use the Voila preview button to see a preview of what our app will look like fully deployed.
#
# Notice the "refresh" button and the "render on save" option. Oftentimes, we want to see the preview as we are developing.

# %% [markdown]
# ### Launching Voila server from the command line

# %% [markdown]
# It will take a minute or so to run the cell below. Thats because a server is being rendered that Voila will run in. It should open in a new tab for us.

# %%
# %%bash
#
# voila 04_dashboard.ipynb

# %% [markdown]
# ## Binder
#
# Okay, all that is well and good, but what if I want to share my app with someone without them having to install the whole thing to their computer? Enter Binder. Binder is a free service provided by NumFocus. With Binder, you can open a GitHub repository full of notebooks in an executable environment, making your code immediately reproducible by anyone, anywhere.

# %% [markdown]
# ## How to use Binder
#
# So for this tutorial, one of the options I gave you was to click a Binder badge that lives in our README.md. How did I make that anyway?
#
# 1. Go to [mybinder.org](mybinder.org)
# 2. Enter in the name of a GitHub repository or URL
# 3. Expand the text and paste it to show a binder badge
#
# ![Screen Shot 2023-06-29 at 8.53.05 AM.png](attachment:dccec723-cbb6-4f33-8c18-d501ddefb1c3.png)

# %% [markdown]
# Okay, let's try it.
#
# 1. Go to [mybinder.org](mybinder.org)
# 2. Enter the repository URL: https://github.com/nicole-brewer/jupyter-web-app-template
# 3. Expand the accordion so you can see and copy the text for the badge
# 4. Paste it into the markdown cell below

# %% [markdown]
# ### Binder Badge for Tutorial
#
# Paste the text here:

# %% [markdown]
# Now click on it and see what happens. Binder images can take a while to load, so be patient.

# %% [markdown]
# ## Using Binder and Voila together
#
# Binder makes it really easy to launch a notebook from Voila instead of JupyterLab. The steps are the same as before, except we will use `Path to a notebook file` option to specify that we want to launch a particular notebook with Voila. We will format the path to a notebook as such: `voila/render/path/to/notebook.ipynb`. In this case, we want to launch our dashboard notebook `04_dashboard.ipynb`.
#
# ![Screen Shot 2023-06-29 at 9.02.46 AM.png](attachment:8164cc58-caa2-49a5-85b8-7df945c2ffac.png)

# %% [markdown]
# Okay, let's try it.
#
# 1. Go to [mybinder.org](mybinder.org)
# 2. Enter the repository URL: https://github.com/nicole-brewer/jupyter-web-app-template
# 3. Specify the path to notebook as `voila/render/04_dashboard.ipynb`
# 3. Expand the accordion so you can see and copy the text for the badge
# 4. Paste it into the markdown cell below

# %% [markdown]
# ### Binder Badge for Dashboard
#
# Paste the text here:

# %% [markdown]
# Now click on it and see what happens.

# %% [markdown]
# # Congratulations!
#
# That concludes this tutorial. Now is a great time for questions and review. Great job everyone!
